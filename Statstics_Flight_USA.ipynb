# %% [markdown]
# <a href="https://colab.research.google.com/github/jamal221/Machine_Learning_Project/blob/main/Statstics_Flight_USA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('D:/project/dataset/CSV_Files/flights_USA/flights_USA.csv')
data.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0           0  2013      1    1     517.0             515        2.0
# 1           1  2013      1    1     533.0             529        4.0
# 2           2  2013      1    1     542.0             540        2.0
# 3           3  2013      1    1     544.0             545       -1.0
# 4           4  2013      1    1     554.0             600       -6.0
#
#    arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 0     830.0             819       11.0  ...   1545   N14228    EWR  IAH
# 1     850.0             830       20.0  ...   1714   N24211    LGA  IAH
# 2     923.0             850       33.0  ...   1141   N619AA    JFK  MIA
# 3    1004.0            1022      -18.0  ...    725   N804JB    JFK  BQN
# 4     812.0             837      -25.0  ...    461   N668DN    LGA  ATL
#
#   air_time  distance  hour  minute            time_hour  \
# 0    227.0      1400     5      15  2013-01-01 05:00:00
# ...

# %%
df_columns=data.columns

# %%
for w in df_columns:
    print ("the type of", w, " is ", data[w].dtype)
# Out:
# the type of Unnamed: 0  is  int64
# the type of year  is  int64
# the type of month  is  int64
# the type of day  is  int64
# the type of dep_time  is  float64
# the type of sched_dep_time  is  int64
# the type of dep_delay  is  float64
# the type of arr_time  is  float64
# the type of sched_arr_time  is  int64
# the type of arr_delay  is  float64
# the type of carrier  is  object
# the type of flight  is  int64
# the type of tailnum  is  object
# the type of origin  is  object
# the type of dest  is  object
# the type of air_time  is  float64
# the type of distance  is  int64
# the type of hour  is  int64
# the type of minute  is  int64
# the type of time_hour  is  object
# the type of name  is  object

# %%
obj=0
for col in df_columns:
    if data[col].dtype=='object':
        obj+=1
print (obj)
# Out:
# 6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
# ...

# %%
data['flight'].dtype
# Out:
# dtype('int64')

# %%
data.mean()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7188\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Unnamed: 0        168387.500000
# year                2013.000000
# month                  6.548510
# day                   15.710787
# dep_time            1349.109947
# sched_dep_time      1344.254840
# dep_delay             12.639070
# arr_time            1502.054999
# sched_arr_time      1536.380220
# arr_delay              6.895377
# flight              1971.923620
# air_time             150.686460
# distance            1039.912604
# hour                  13.180247
# minute                26.230100
# dtype: float64

# %%
data['arr_delay'].mean()
# Out:
# 6.89537675731489

# %%
data['arr_delay'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['arr_delay']
# Out:
# 0         11.0
# 1         20.0
# 2         33.0
# 3        -18.0
# 4        -25.0
#           ...
# 336771     NaN
# 336772     NaN
# 336773     NaN
# 336774     NaN
# 336775     NaN
# Name: arr_delay, Length: 336776, dtype: float64

# %%
from scipy import stats
stats.trim_mean(data['arr_delay'], 0.1)
# Out:
# 0.9612355338465307

# %%
data['arr_time'].mean()
# Out:
# 1502.0549985825894

# %%
data['arr_time'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
data.corr()
# Out:
#                 Unnamed: 0  year     month       day  dep_time  \
# Unnamed: 0        1.000000   NaN  0.071779  0.087852  0.002172
# year                   NaN   NaN       NaN       NaN       NaN
# month             0.071779   NaN  1.000000  0.002942 -0.003932
# day               0.087852   NaN  0.002942  1.000000 -0.000467
# dep_time          0.002172   NaN -0.003932 -0.000467  1.000000
# sched_dep_time    0.004076   NaN -0.004573 -0.000014  0.954617
# dep_delay         0.049713   NaN -0.020057  0.000420  0.260231
# arr_time         -0.024680   NaN -0.002520 -0.005537  0.660779
# sched_arr_time   -0.013373   NaN -0.004173 -0.002403  0.784682
# arr_delay         0.018613   NaN -0.017382 -0.000319  0.232306
# flight            0.002676   NaN -0.000834 -0.001791  0.041957
# air_time         -0.032866   NaN  0.010924  0.002236 -0.014619
# distance          0.012526   NaN  0.021636  0.003041 -0.013998
# hour              0.003150   NaN -0.005227 -0.000055  0.953306
# ...

# %%
plt.scatter(data['hour'],data['arr_delay'])

# %%
data['arr_time'].mean()
# Out:
# 1502.0549985825894

# %%
std_data=data['arr_delay'].std()

# %%
mean_data=data['arr_delay'].mean()

# %%
range(len(data['arr_delay']))
# Out:
# range(0, 336776)

# %%
sum=0
for i in range(len(data['arr_delay'])):
    if i >= mean_data-std_data and i<= mean_data+std_data:
        sum+=1
print (sum)
# Out:
# 52

# %%
print("std_data",std_data)
print("mean_data",mean_data)
print("mean_data-std_data=  ",mean_data-std_data )
print("mean_data+std_data=  ", mean_data+std_data)
# Out:
# std_data 44.63329169019526
# mean_data 6.89537675731489
# mean_data-std_data=   -37.737914932880365
# mean_data+std_data=   51.52866844751015

# %%
data_between=data['arr_delay'][data['arr_delay']>=(mean_data-std_data)][data['arr_delay']>=(mean_data+std_data)]
(len(data_between)/len(data['arr_delay']))*100
# Out:
# 9.781872817540442

# %% [markdown]
# # The above code shows that 9 percent of data between (mean-std) and (mean+std), at this time we can say that this data is not normal. Because if 68.2 of data have to in this range, so we can prove that the datframe is normal

# %%
list1=list(data['arr_delay'][data['arr_delay']>=(mean_data-std_data)][data['arr_delay']>=(mean_data+std_data)])
print(list1)
# Out:
# [137.0, 851.0, 123.0, 145.0, 78.0, 81.0, 53.0, 93.0, 56.0, 78.0, 73.0, 60.0, 103.0, 84.0, 66.0, 65.0, 83.0, 127.0, 52.0, 60.0, 125.0, 115.0, 91.0, 136.0, 65.0, 123.0, 67.0, 78.0, 72.0, 80.0, 59.0, 67.0, 96.0, 56.0, 68.0, 61.0, 107.0, 123.0, 68.0, 66.0, 65.0, 138.0, 116.0, 338.0, 94.0, 263.0, 52.0, 78.0, 127.0, 54.0, 81.0, 151.0, 166.0, 174.0, 75.0, 222.0, 83.0, 123.0, 91.0, 61.0, 55.0, 250.0, 142.0, 246.0, 73.0, 127.0, 191.0, 69.0, 73.0, 456.0, 154.0, 90.0, 75.0, 56.0, 142.0, 171.0, 58.0, 70.0, 65.0, 57.0, 173.0, 84.0, 62.0, 99.0, 52.0, 97.0, 72.0, 85.0, 63.0, 73.0, 98.0, 54.0, 102.0, 207.0, 83.0, 288.0, 96.0, 107.0, 323.0, 60.0, 85.0, 136.0, 65.0, 119.0, 59.0, 130.0, 109.0, 63.0, 69.0, 81.0, 368.0, 67.0, 102.0, 96.0, 70.0, 122.0, 82.0, 82.0, 131.0, 69.0, 71.0, 54.0, 166.0, 80.0, 141.0, 69.0, 107.0, 99.0, 120.0, 85.0, 106.0, 81.0, 77.0, 55.0, 158.0, 136.0, 180.0, 102.0, 116.0, 64.0, 68.0, 84.0, 176.0, 88.0, 182.0, 82.0, 83.0, 59.0, 157.0, 58.0, 359.0, 130.0, 82.0, 89.0, 252.0, 53.0, 
# ...

# %% [markdown]
# # Please explaine what is the List1? about the data

# %%
data['arr_delay'].median()
# Out:
# -5.0

# %%
data['arr_delay'].mode()
# Out:
# 0   -13.0
# dtype: float64

# %%
data['arr_delay'][data['arr_delay'] < 100].hist(bins=80)
# Out:
# <AxesSubplot:>

# %%
data['arr_delay'].hist(bins=80)
# Out:
# <AxesSubplot:>
